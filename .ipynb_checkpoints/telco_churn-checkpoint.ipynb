# %%
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import datetime as dt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 6)

# %%
import sklearn
from sklearn.metrics import (
    mean_squared_error as mse,
    mean_absolute_error as mae,
    mean_absolute_percentage_error as mape
)

# %%
def performance(actual, predicted):
    print('MAE', round(mae(actual, predicted), 3))
    print('RMSE', round(mse(actual, predicted)**0.5, 3))
    print('MAPE', round(mape(actual, predicted), 3))

# %%
mobile_sales = yf.Ticker('RELIANCE.NS').history(period='1y')[['Open']]

# %%
mobile_sales.index = mobile_sales.index.strftime('%Y-%m-%d')

# %%
mobile_sales.index = pd.to_datetime(mobile_sales.index, errors='coerce')

# %%
mobile_sales
# Out:
#                    Open
# Date
# 2023-12-27  1282.266405
# 2023-12-28  1286.140066
# 2023-12-29  1296.717943
# 2024-01-01  1281.546360
# 2024-01-02  1283.756206
# ...                 ...
# 2024-12-20  1224.000000
# 2024-12-23  1215.000000
# 2024-12-24  1222.300049
# 2024-12-26  1224.250000
# 2024-12-27  1218.300049
#
# [247 rows x 1 columns]

# %%
mobile_sales.rename(columns = {"Open":"Sales"}, inplace=True)

# %%
mobile_sales
# Out:
#                   Sales
# Date
# 2023-12-27  1282.266405
# 2023-12-28  1286.140066
# 2023-12-29  1296.717943
# 2024-01-01  1281.546360
# 2024-01-02  1283.756206
# ...                 ...
# 2024-12-20  1224.000000
# 2024-12-23  1215.000000
# 2024-12-24  1222.300049
# 2024-12-26  1224.250000
# 2024-12-27  1218.300049
#
# [247 rows x 1 columns]

# %%
mobile_sales.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
mobile_sales.Sales = mobile_sales.Sales.interpolate(method= 'linear')
mobile_sales.Sales
# Out:
# Date
# 2023-12-27    1282.266405
# 2023-12-28    1286.140066
# 2023-12-29    1296.717943
# 2024-01-01    1281.546360
# 2024-01-02    1283.756206
#                  ...
# 2024-12-20    1224.000000
# 2024-12-23    1215.000000
# 2024-12-24    1222.300049
# 2024-12-26    1224.250000
# 2024-12-27    1218.300049
# Name: Sales, Length: 247, dtype: float64

# %%
mobile_sales.Sales.plot(style='-o')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Clipping

# %%
mobile_sales.describe()
# Out:
#              Sales
# count   247.000000
# mean   1417.971984
# std      87.131892
# min    1215.000000
# 25%    1350.501642
# 50%    1446.919903
# 75%    1474.476988
# max    1593.595776

# %%
#mobile_sales.Sales = mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.98), lower=mobile_sales.Sales.quantile(0.02))

# %%
df = mobile_sales
Q1 = df.quantile(0.05)
Q3 = df.quantile(0.95)
IQR = Q3 - Q1

df = df[((df > Q1) & (df < Q3)).any(axis=1)]

# %%
mobile_sales = df

# %%
 #mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.85), lower=mobile_sales.Sales.quantile(0.15))

# %%
train_max_date = mobile_sales.index[-12]
train_x = mobile_sales.loc[mobile_sales.index < mobile_sales.index[-12]]
test_x = mobile_sales.loc[mobile_sales.index >= mobile_sales.index[-12]]

# %% [markdown]
# ## Moving Average

# %%
#Code for imputation using CENTERED moving average
#train_x.rolling(12, center=True).mean().plot();

train_x.Sales.plot(style= '-o')
train_x.Sales.rolling(12).mean().plot();

# %%
pred_ = train_x.Sales.copy().values

for i in range(12):
    pred_ = np.append(pred_, pred_[-3:].mean())

test_x['pred'] = pred_[-12:]
# Out:
# C:\Users\ryanr\AppData\Local\Temp\ipykernel_25372\3823010773.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test
#        1403.92504883, 1393.5       , 1372.97497559, 1397.52502441,
#        1380.02502441, 1370.        , 1379.44995117, 1358.52502441,
#        1340.        , 1365.69995117, 1352.17504883, 1367.125     ,
#        1369.19995117, 1337.5       , 1335.27502441, 1343.5       ,
#        1337.        , 1328.09997559, 1335.        , 1340.        ,
#        1333.05004883, 1337.84997559, 1293.        , 1310.        ,
#        1324.        , 1297.65002441, 1278.94995117, 1275.55004883,
#        1270.25      , 1267.59997559, 1290.        , 1294.94995117,
#        1293.5       , 1292.81665039, 1293.75553385, 1293.35739475,
#        1293.30985966, 1293.47426276, 1293.38050572, 1293.38820938,
#        1293.41432595, 1293.39434702, 1293.39896078, 1293.40254459,
#        1293.39861746])

# %%
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE 52.022
# RMSE 55.467
# MAPE 0.042

# %% [markdown]
# ## Simple Exponential Smoothing

# %%
#y_t+1_hat = alpha * y_t + (1 - alpha) * y_hat_t
model = sm.tsa.SimpleExpSmoothing(mobile_sales.Sales).fit(smoothing_level = 0.2)
pred = model.forecast(12)
# Out:
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
mobile_sales.Sales.plot(style='-o')
pred.plot(label='ses_pred', style='-o')
plt.legend()

# %% [markdown]
# ## Double Exponential Smoothing

# %%
# DES = SES + Drift Method (Slope method)

# %%
#trend = 'add' is used to implement DES
model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales, trend='add').fit()
model.fittedvalues.plot(label='fitted')
mobile_sales.Sales.plot(label = 'original')
plt.show()
# Out:
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model.forecast(12)
# Out:
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 247    1228.768866
# 248    1228.556384
# 249    1228.343902
# 250    1228.131420
# 251    1227.918939
# 252    1227.706457
# 253    1227.493975
# 254    1227.281493
# 255    1227.069011
# 256    1226.856530
# 257    1226.644048
# 258    1226.431566
# dtype: float64

# %%
pred = model.forecast(12)
mobile_sales.Sales.tail(100).plot(style = '-o', label = 'actual')
pred.plot(style = '-o', label = 'predicted')
plt.legend()
# Out:
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
mobile_sales.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
pred
# Out:
# 247    1228.768866
# 248    1228.556384
# 249    1228.343902
# 250    1228.131420
# 251    1227.918939
# 252    1227.706457
# 253    1227.493975
# 254    1227.281493
# 255    1227.069011
# 256    1226.856530
# 257    1226.644048
# 258    1226.431566
# dtype: float64

# %%
#Performance
test_x['pred'] = pred.values
performance(test_x['Sales'], test_x['pred'])
# Out:
# MAE 20.37
# RMSE 28.135
# MAPE 0.016
# C:\Users\ryanr\AppData\Local\Temp\ipykernel_25372\353719954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_x['pred'] = pred.values

# %%
#seasonal = 'add' to implement TES
model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales, trend = 'add', seasonal = 'add').fit()
model.fittedvalues.plot(label='fitted')
mobile_sales.Sales.plot(label='actual')
# Out:
# C:\Users\ryanr\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\holtwinters\model.py:260, in ExponentialSmoothing.__init__(self, endog, trend, damped_trend, seasonal, seasonal_periods, initialization_method, initial_level, initial_trend, initial_seasonal, use_boxcox, bounds, dates, freq, missing)
#     259 try:
# --> 260     self.seasonal_periods = freq_to_period(self._index_freq)
#     261 except Exception:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\tsatools.py:805, in freq_to_period(freq)
#     804     freq = to_offset(freq)  # go ahead and standardize
# --> 805 assert isinstance(freq, offsets.DateOffset)
#     806 freq = freq.rule_code.upper()
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[177], line 2
#       1 #seasonal = 'add' to implement TES
# ----> 2 model = sm.tsa.ExponentialSmoothing(mobile_sales.Sales, trend = 'add', seasonal = 'add').fit()
#       3 model.fittedvalues.plot(label='fitted')
#       4 mobile_sales.Sales.plot(label='actual')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\holtwinters\model.py:262, in ExponentialSmoothing.__init__(self, endog, trend, damped_trend, seasonal, seasonal_periods, initialization_method, initial_level, initial_trend, initial_seasonal, use_boxcox, bounds, dates, freq, missing)
#     260         self.seasonal_periods = freq_to_period(self._index_freq)
#     261     except Exception:
# --> 262         raise ValueError(
#     263             "seasonal_periods has not been provided and index "
#     264             "does not have a known freq. You must provide "
#     265             "seasonal_periods"
#     266         )
#     267 if self.seasonal_periods <= 1:
#     268     raise ValueError("seasonal_periods must be larger than 1.")
#
# ValueError: seasonal_periods has not been provided and index does not have a known freq. You must provide seasonal_periods

# %%
pred = model.forecast(12)
mobile_sales.Sales.tail(100).plot(style = '-o', label = 'actual')
pred.plot(style = '-o', label = 'actual')
plt.legend()

# %%
test_x['pred'] = pred.values
test_x.plot(style='-o')
performance(test_x['Sales'], test_x['pred'])

# %% [markdown]
# ## Stationarity

# %%
##Dickey-Fuller test
## Returns 
#test statistic
# p-value
# etc.
sm.tsa.stattools.adfuller(mobile_sales.Sales)

# %%
# H0: TS is not stationary
# H1: 

#Since it is not less than 0.95
#We accept the null hypothesis
sm.tsa.stattools.adfuller(mobile_sales.Sales)[1]

# %%
def adf_test(data, significance_level = 0.05):
    pvalue = sm.tsa.stattools.adfuller(data)[1]
    if pvalue <= significance_level:
        print('Sequence is stationary')
    else:
        print('Sequence is not stationary')

# %%
adf_test(mobile_sales.Sales)

# %% [markdown]
# ## Non-stationary to stationary

# %%
model = sm.tsa.seasonal_decompose(mobile_sales.Sales, model='additive')
model.plot();

# %%
model.resid.plot()

# %%
#Bravo! Sequence is stationary! This can go into the ARIMA model
adf_test(model.resid.dropna())

# %%
## Another way! Using differencing!
## .diff(1) removes trend
## .diff(12) removes seasonality
mobile_sales.Sales.diff(1).diff(12).plot()

# %%
adf_test(mobile_sales.Sales.diff(1).diff(12).dropna())

# %% [markdown]
# ## Autocorrelation

# %%
original = mobile_sales.Sales[1:]
shift_1 = mobile_sales.Sales.shift(1).dropna()
np.corrcoef(original, shift_1)

# %%
## Keep going. At 12, corr is the highest!
original = mobile_sales.Sales[12:]
shift_1 = mobile_sales.Sales.shift(12).dropna()
np.corrcoef(original, shift_1)

# %%
mobile_sales.Sales.shift(12).dropna()[0]

# %%
#Declare an empty corr array to store the shifted array
corr = []
for lag in range(36):
    corr.append(np.corrcoef(mobile_sales.Sales[lag:], mobile_sales.Sales.shift(lag).dropna())[0][1])

plt.stem(np.arange(36), corr)

# %%
#Method 2 
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(mobile_sales.Sales, lags=36)
